# %% [markdown]
# <a href="https://colab.research.google.com/github/jarekwan/PROJEKT_SCANNER/blob/main/MAIN_P.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.kill(os.getpid(), 9)

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append("/content/drive/MyDrive/projekt_test")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import i uruchom
import modul_pobieranie

# %%
modul_pobieranie.run()
# Out:
# podaj ticker dla danych z api twelve data: ASM
# ticker: ASM
# zrodlo: twelve_data
# liczba notowan: 5000
# zapisano json: /content/drive/MyDrive/projekt_test/ASM_twelve.json
# zapisano csv: /content/drive/MyDrive/projekt_test/ASM_twelve.csv
#          data  open  high   low  close  volume
# 0  2006-05-12  3.39  3.41  3.14   3.20   26900
# 1  2006-05-15  3.25  3.25  2.61   2.81   93900
# 2  2006-05-16  2.70  3.14  2.70   2.92   78000
# 3  2006-05-17  2.95  3.19  2.76   2.77   51700
# 4  2006-05-18  2.50  2.75  2.46   2.53   77000
# 5  2006-05-19  2.55  3.17  2.11   2.70  136100
# 6  2006-05-22  2.69  2.70  2.69   2.69    9800
# 7  2006-05-23  2.69  3.15  2.69   2.80   52900
# 8  2006-05-24  2.70  2.87  2.69   2.86   13800
# 9  2006-05-25  2.85  2.85  2.70   2.70   32300
