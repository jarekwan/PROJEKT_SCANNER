# %% [markdown]
# <a href="https://colab.research.google.com/github/jarekwan/PROJEKT_SCANNER/blob/main/MAIN_P.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.kill(os.getpid(), 9)

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append("/content/drive/MyDrive/projekt_test")
# Out:
# Mounted at /content/drive

# %%
# import i uruchom
import modul_pobieranie
import modul_model_danych

# %%
modul_pobieranie.run()
# Out:
# podaj ticker dla danych z api twelve data: ASM
# ticker: ASM
# zrodlo: twelve_data
# liczba notowan: 5000
# zapisano json: /content/drive/MyDrive/projekt_test/ASM_twelve.json
# zapisano csv: /content/drive/MyDrive/projekt_test/ASM_twelve.csv
#          data  open  high   low  close  volume
# 0  2006-10-03  1.63  1.63  1.47   1.47   18400
# 1  2006-10-04  1.50  1.54  1.45   1.48   20200
# 2  2006-10-05  1.50  1.50  1.48   1.48    8100
# 3  2006-10-06  1.55  1.55  1.48   1.53   13000
# 4  2006-10-09  1.52  1.52  1.45   1.45    7600
# 5  2006-10-10  1.51  1.51  1.42   1.42   17200
# 6  2006-10-11  1.49  1.49  1.38   1.38    4900
# 7  2006-10-12  1.40  1.51  1.32   1.50   19300
# 8  2006-10-13  1.55  1.55  1.51   1.55    8100
# 9  2006-10-16  1.57  1.60  1.57   1.57    6800

# %%
modul_model_danych.run()
